# %%
import pandas as pd

# %%
data=pd.read_json(r'linkext8.json')
data
# Out:
#                user_name          phone_number  announcement_id update_date  \
# 0                   Zaur     +994 55 344 65 05          72971.0  18.07.2023
# 1          Aytəkin xanım     +994 77 477 40 70          72975.0  18.07.2023
# 2               Azər Bəy     +994 55 318 65 05          72976.0  18.07.2023
# 3               Şəmistan     +994 77 444 27 10          72974.0  18.07.2023
# 4                 Samirə     +994 70 766 85 85          72973.0  18.07.2023
# ...                  ...                   ...              ...         ...
# 18399  Oktay Dərələyəzli     +994 70 804 57 77          73004.0  18.07.2023
# 18400  Oktay Dərələyəzli     +994 70 804 57 77          73003.0  18.07.2023
# 18401       Məhərrəm bəy     +994 77 220 23 39          73002.0  18.07.2023
# 18402          Turan bəy     +994 51 277 87 31          73005.0  18.07.2023
# 18403          Turan bəy     +994 51 277 87 31          73007.0  18.07.2023
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18404 entries, 0 to 18403
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   user_name        18403 non-null  object
#  1   phone_number     18403 non-null  object
#  2   announcement_id  18403 non-null  float64
#  3   update_date      18403 non-null  object
#  4   baxis_sayi       18403 non-null  float64
#  5   area             18403 non-null  object
#  6   flat             17923 non-null  object
#  7   room_count       17923 non-null  float64
#  8   document_type    18403 non-null  object
#  9   repair_type      17923 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 1.4+ MB

# %%
# data['phone_number_cleaned'] = data['phone_number'].str.replace(r'\D', '').str[-9:]
# data

# %%
# data['phone_number_cleared'] = data['phone_number'].str.replace(r'\D', '').str[-9:].str.replace(r'(\d{3})(\d{3})(\d{3})', r'\1\2\3')
# data

# %%
data['phone_numbers_cleaned'] = data['phone_number'].str.replace('\s', '', regex=True).str[-9:]
data.head()
# Out:
#        user_name          phone_number  announcement_id update_date  \
# 0           Zaur     +994 55 344 65 05          72971.0  18.07.2023
# 1  Aytəkin xanım     +994 77 477 40 70          72975.0  18.07.2023
# 2       Azər Bəy     +994 55 318 65 05          72976.0  18.07.2023
# 3       Şəmistan     +994 77 444 27 10          72974.0  18.07.2023
# 4         Samirə     +994 70 766 85 85          72973.0  18.07.2023
#
#    baxis_sayi       area   flat  room_count    document_type repair_type  \
# 0        27.0   90.00 m²  18/18         2.0  Çıxarış (Kupça)         Əla
# 1        25.0   60.00 m²    9/6         3.0  Çıxarış (Kupça)        Orta
# 2        20.0   95.00 m²    1/1         4.0  Çıxarış (Kupça)        Orta
# 3        14.0  110.00 m²    1/1         3.0  Çıxarış (Kupça)         Əla
# 4        22.0  104.00 m²    9/9         5.0  Çıxarış (Kupça)        Orta
#
#   phone_numbers_cleaned
# 0             553446505
# 1             774774070
# 2             553186505
# ...

# %%
data.to_csv(r"data.csv", sep=',', encoding='utf-8', header='true')
data.to_parquet(r"data.parquet")
data.to_excel('data.xlsx', engine='xlsxwriter')
